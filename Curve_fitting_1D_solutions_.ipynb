# %%
##############################################################################################################
# RUN THIS CODE BLOCK FIRST, it will load dependencies / install them if your system does not already have them.
##############################################################################################################

# tensorflow
try:
    # Try to import TensorFlow
    import tensorflow as tf
    print(f"TensorFlow is already installed. Version: {tf.__version__}")
except ImportError as e:
    # TensorFlow is not installed; install it
    print("TensorFlow is not installed. Installing TensorFlow...")
    # !pip install tensorflow
    import tensorflow as tf
    print(f"Successfully installed TensorFlow. Version: {tf.__version__}")

# pyDOE
try:
    # Try to import pyDOE
    import pyDOE
    print(f"pyDOE is already installed.")
except ImportError as e:
    # pyDOE is not installed; install it
    print("pyDOE is not installed. Installing pyDOE...")
    # !pip install pyDOE
    import pyDOE
    print(f"Successfully installed pyDOE.")

import tensorflow_probability as tfp
from tensorflow.keras.layers import InputLayer, Dense, Layer
import numpy as np
import sys
import matplotlib
import matplotlib.pyplot as plt
import time

np.random.seed(123)
tf.random.set_seed(123)
# Out:
# TensorFlow is already installed. Version: 2.18.0
# pyDOE is not installed. Installing pyDOE...
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (1.14.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18170 sha256=41324bd40ca996c5600ee4f3fca8ea706a3c591040da9c6e933240b44ddbbf0a
#   Stored in directory: /root/.cache/pip/wheels/84/20/8c/8bd43ba42b0b6d39ace1219d6da1576e0dac81b12265c4762e
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8
# Successfully installed pyDOE.

# %%
print("Below are the versions that this Colab notebook uses:")
print("Python version: " + sys.version)
print("matplotlib version: " + matplotlib.__version__)
print("TensorFlow version: " + tf.__version__)

print("")

print("Below are the versions that successfully run this script:")
print("Python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]")
print("matplotlib version: 3.7.1")
print("TensorFlow version: 2.15.0")
# Out:
# Below are the versions that this Colab notebook uses:
# Python version: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# matplotlib version: 3.10.0
# TensorFlow version: 2.18.0
#
# Below are the versions that successfully run this script:
# Python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# matplotlib version: 3.7.1
# TensorFlow version: 2.15.0

# %%
class NeuralNet:
    # Initialize the class
    def __init__(self, t_train, x_train, t_test, x_test, layers, t_min, t_max):
        self.t_train = t_train
        self.x_train = x_train
        self.t_test = t_test
        self.x_test = x_test
        self.loss_history = {"train": [], "test": []}

        # Initialize NNs with given number of layers and domain bounds [t_min, tmax]
        self.t_min = t_min
        self.t_max = t_max
        self.initialize_nn(layers)

    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)

    def initialize_nn(self, layers):
        """Functions used to establish the initial neural network"""
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32))
            weights.append(W)
            biases.append(b)
        self.weights = weights
        self.biases = biases
        self.trainable_variables = self.weights + self.biases

    def net(self, X):
        H = 2.0 * (X - self.t_min) / (self.t_max - self.t_min) - 1.0
        for l in range(0, len(self.weights) - 1):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    @tf.function
    def loss_train(self):
        x_pred = self.net(self.t_train)
        loss = tf.reduce_mean(tf.square(self.x_train - x_pred)) * 10
        return loss

    @tf.function
    def loss_test(self):
        x_pred = self.net(self.t_test)
        loss = tf.reduce_mean(tf.square(self.x_test - x_pred)) * 10
        return loss

    def get_test_error(self):
        x_pred = self.net(self.t_test)
        error_x = tf.norm(self.x_test - x_pred, 2) / tf.norm(self.x_test, 2)
        return error_x

    def train(self, nIter: int, learning_rate: float, idxOpt: int):
      """Function used for training the model"""
      if idxOpt == 1:
          # mode 1: running the Gradient Descent optimization
          self.optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
      elif idxOpt == 2:
          # mode 2: running the Adam optimization
          self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
      else:
          raise ValueError("Unsupported idxOpt")

      varlist = self.trainable_variables
      start_time = time.time()

      for it in range(nIter):
          with tf.GradientTape() as tape:
              loss_value = self.loss_train()

          # Compute gradients
          gradients = tape.gradient(loss_value, varlist)

          # Apply gradients
          self.optimizer.apply_gradients(zip(gradients, varlist))

          # Print training progress
          if it % 100 == 0:
              elapsed = time.time() - start_time
              loss_train = loss_value.numpy()
              loss_test = self.loss_test().numpy()
              self.loss_history["train"].append(loss_train)
              self.loss_history["test"].append(loss_test)
              print('It: %d, Train Loss: %.3e, Test Loss: %.3e, Time: %.2f' %
                    (it, loss_train, loss_test, elapsed))
              start_time = time.time()


# %matplotlib inline
def plot(t_all, x_all, pred_all, t_train, x_train, title: str):
    fig = plt.figure(figsize=(21, 24))

    ax = plt.subplot(311)
    ax.plot(t_all, x_all, "r", label="Exact Solution")
    ax.plot(t_all, pred_all, "b--", label="Prediction")
    ax.scatter(t_train, x_train, s=30, c="g", label="Training Data Point")
    ax.legend()
    ax.set_xlabel("$t$", fontsize = 15)
    ax.set_ylabel("$x$", fontsize = 15, rotation = 0)
    ax.set_title("$Fitting$", fontsize = 15)

    ax = plt.subplot(312)
    ax.plot(t_all, pred_all - x_all, "b-")
    ax.set_xlabel("$t$", fontsize = 15)
    ax.set_ylabel("Prediction - Exact Solution", fontsize = 15, rotation = 90)
    ax.set_title("Difference between Prediction and Exact Solution", fontsize = 15)

    ax = plt.subplot(313)
    loss_train = np.array(model.loss_history["train"])
    loss_test = np.array(model.loss_history["test"])
    ax.scatter(np.arange(loss_train.size) * 100, loss_train, s=30, marker="x", label="Train Loss")
    ax.scatter(np.arange(loss_train.size) * 100, loss_test, s=30, marker="+", label="Test Loss")
    ax.legend()
    ax.set_xlabel("$iterations$", fontsize = 15)
    ax.set_ylabel("Loss", fontsize = 15, rotation = 90)
    ax.set_yscale("log")
    ax.set_title('Loss Curve', fontsize = 15)

    plt.gcf().text(0.02, 0.9, title, fontsize=30)

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = x = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.1, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_train, x_train, title="Gradient Descent Optimization")
# Out:
# It: 0, Train Loss: 5.204e+00, Test Loss: 6.208e+00, Time: 0.68
# It: 100, Train Loss: 5.232e+04, Test Loss: 5.575e+04, Time: 4.41
# It: 200, Train Loss: 1.344e+05, Test Loss: 1.362e+05, Time: 2.97
# It: 300, Train Loss: 1.155e+05, Test Loss: 1.237e+05, Time: 3.23
# It: 400, Train Loss: 4.396e+04, Test Loss: 4.383e+04, Time: 3.82
# It: 500, Train Loss: 2.645e+04, Test Loss: 2.517e+04, Time: 4.16
# It: 600, Train Loss: 1.385e+04, Test Loss: 1.302e+04, Time: 3.05
# It: 700, Train Loss: 6.655e+03, Test Loss: 6.334e+03, Time: 3.25
# It: 800, Train Loss: 1.732e+04, Test Loss: 1.652e+04, Time: 1.50
# It: 900, Train Loss: 1.126e+04, Test Loss: 1.197e+04, Time: 2.27
# It: 1000, Train Loss: 7.533e+03, Test Loss: 7.162e+03, Time: 1.59
# It: 1100, Train Loss: 7.710e+03, Test Loss: 7.368e+03, Time: 1.45
# It: 1200, Train Loss: 2.678e+03, Test Loss: 2.818e+03, Time: 1.48
# It: 1300, Train Loss: 1.306e+03, Test Loss: 1.297e+03, Time: 1.48
# It: 1400, Train Loss: 1.480e+03, Test Loss: 1.374e+03, Time: 1.46
# It: 1500, Train Loss: 1.690e+03, Test Loss: 1.591e+03, Time: 1.52
# It: 1600, Train Loss: 1.559e+03, Test Loss: 1.534e+03, Time: 1.64
# It: 1700, Train Loss: 2.562e+03, Test Loss: 2.597e+03, Time: 2.23
# It: 1800, Train Loss: 2.599e+03, Test Loss: 2.433e+03, Time: 1.53
# It: 1900, Train Loss: 6.730e+03, Test Loss: 6.154e+03, Time: 1.48
# Training time: 46.9286
# Norm of Differnece: 3.016040e+01

# %% [markdown]
# ### Tasks
# 1. Find the learning rate that makes the loss converge
# 2. Find the minimum amount of training data needed to make the loss converge
# 3. Effects of activation function
# 4. Effects of noisy data (e.g. Gausian noise)
# 5. Find the parameters that can cause overfitting (test loss increases over iterations). The maximum iterations you can use is 20k.

# %% [markdown]
# Q.1 lEARNING RATE

# %%
model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all,t_train, x_train, title="Learning rate 0.01")
# Out:
# It: 0, Train Loss: 5.553e+00, Test Loss: 5.177e+00, Time: 0.14
# It: 100, Train Loss: 5.055e+00, Test Loss: 4.822e+00, Time: 1.19
# It: 200, Train Loss: 5.054e+00, Test Loss: 4.821e+00, Time: 1.17
# It: 300, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 1.21
# It: 400, Train Loss: 5.052e+00, Test Loss: 4.819e+00, Time: 1.18
# It: 500, Train Loss: 5.051e+00, Test Loss: 4.818e+00, Time: 1.16
# It: 600, Train Loss: 5.050e+00, Test Loss: 4.817e+00, Time: 1.69
# It: 700, Train Loss: 5.049e+00, Test Loss: 4.816e+00, Time: 1.52
# It: 800, Train Loss: 5.047e+00, Test Loss: 4.815e+00, Time: 1.21
# It: 900, Train Loss: 5.044e+00, Test Loss: 4.812e+00, Time: 1.20
# It: 1000, Train Loss: 5.039e+00, Test Loss: 4.807e+00, Time: 1.21
# It: 1100, Train Loss: 5.024e+00, Test Loss: 4.794e+00, Time: 1.21
# It: 1200, Train Loss: 4.951e+00, Test Loss: 4.729e+00, Time: 1.20
# It: 1300, Train Loss: 5.449e+00, Test Loss: 5.278e+00, Time: 1.22
# It: 1400, Train Loss: 1.559e+00, Test Loss: 1.393e+00, Time: 1.19
# It: 1500, Train Loss: 6.472e-01, Test Loss: 5.613e-01, Time: 1.30
# It: 1600, Train Loss: 4.242e-01, Test Loss: 3.633e-01, Time: 1.74
# It: 1700, Train Loss: 3.622e-02, Test Loss: 2.903e-02, Time: 1.37
# It: 1800, Train Loss: 2.924e-03, Test Loss: 3.187e-03, Time: 1.19
# It: 1900, Train Loss: 2.538e-03, Test Loss: 2.750e-03, Time: 1.19
# Training time: 25.7495
# Norm of Differnece: 2.160834e-02

# %%
model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.001, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_train, x_train, title="Learning rate 0.001")
# Out:
# It: 0, Train Loss: 6.304e+00, Test Loss: 6.242e+00, Time: 0.22
# It: 100, Train Loss: 5.054e+00, Test Loss: 4.825e+00, Time: 1.31
# It: 200, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 1.17
# It: 300, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 1.20
# It: 400, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 1.18
# It: 500, Train Loss: 5.052e+00, Test Loss: 4.820e+00, Time: 1.19
# It: 600, Train Loss: 5.052e+00, Test Loss: 4.819e+00, Time: 1.21
# It: 700, Train Loss: 5.052e+00, Test Loss: 4.819e+00, Time: 1.19
# It: 800, Train Loss: 5.052e+00, Test Loss: 4.819e+00, Time: 1.20
# It: 900, Train Loss: 5.051e+00, Test Loss: 4.819e+00, Time: 1.42
# It: 1000, Train Loss: 5.051e+00, Test Loss: 4.818e+00, Time: 1.78
# It: 1100, Train Loss: 5.051e+00, Test Loss: 4.818e+00, Time: 1.18
# It: 1200, Train Loss: 5.050e+00, Test Loss: 4.818e+00, Time: 1.19
# It: 1300, Train Loss: 5.050e+00, Test Loss: 4.818e+00, Time: 1.18
# It: 1400, Train Loss: 5.050e+00, Test Loss: 4.817e+00, Time: 1.18
# It: 1500, Train Loss: 5.049e+00, Test Loss: 4.817e+00, Time: 1.18
# It: 1600, Train Loss: 5.049e+00, Test Loss: 4.817e+00, Time: 1.16
# It: 1700, Train Loss: 5.049e+00, Test Loss: 4.816e+00, Time: 1.19
# It: 1800, Train Loss: 5.048e+00, Test Loss: 4.816e+00, Time: 1.17
# It: 1900, Train Loss: 5.048e+00, Test Loss: 4.815e+00, Time: 1.47
# Training time: 25.8167
# Norm of Differnece: 9.645635e-01

# %% [markdown]
# ### Q.2 TRAIN/TEST RATIO

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_train, x_train, title="Train/Test Set Ratio 0.8/0.2")
# Out:
# It: 0, Train Loss: 5.981e+00, Test Loss: 5.427e+00, Time: 0.14
# It: 100, Train Loss: 4.967e+00, Test Loss: 5.171e+00, Time: 1.21
# It: 200, Train Loss: 4.965e+00, Test Loss: 5.169e+00, Time: 1.17
# It: 300, Train Loss: 4.963e+00, Test Loss: 5.167e+00, Time: 1.78
# It: 400, Train Loss: 4.960e+00, Test Loss: 5.165e+00, Time: 1.52
# It: 500, Train Loss: 4.957e+00, Test Loss: 5.161e+00, Time: 1.19
# It: 600, Train Loss: 4.950e+00, Test Loss: 5.153e+00, Time: 1.18
# It: 700, Train Loss: 4.923e+00, Test Loss: 5.124e+00, Time: 1.19
# It: 800, Train Loss: 2.330e-02, Test Loss: 1.900e-02, Time: 1.20
# It: 900, Train Loss: 3.057e-03, Test Loss: 3.096e-03, Time: 1.20
# It: 1000, Train Loss: 2.912e-03, Test Loss: 2.952e-03, Time: 1.20
# It: 1100, Train Loss: 2.784e-03, Test Loss: 2.823e-03, Time: 1.19
# It: 1200, Train Loss: 2.668e-03, Test Loss: 2.708e-03, Time: 1.42
# It: 1300, Train Loss: 2.564e-03, Test Loss: 2.603e-03, Time: 1.83
# It: 1400, Train Loss: 2.469e-03, Test Loss: 2.509e-03, Time: 1.24
# It: 1500, Train Loss: 2.383e-03, Test Loss: 2.422e-03, Time: 1.21
# It: 1600, Train Loss: 2.304e-03, Test Loss: 2.343e-03, Time: 1.21
# It: 1700, Train Loss: 2.232e-03, Test Loss: 2.270e-03, Time: 1.23
# It: 1800, Train Loss: 2.165e-03, Test Loss: 2.202e-03, Time: 1.23
# It: 1900, Train Loss: 2.103e-03, Test Loss: 2.140e-03, Time: 1.20
# Training time: 26.0446
# Norm of Differnece: 1.964369e-02

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.1
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_train, x_train, title="Train/Test Set Ratio 0.1/0.9")
# Out:
# It: 0, Train Loss: 5.798e+00, Test Loss: 5.027e+00, Time: 0.16
# It: 100, Train Loss: 5.760e+00, Test Loss: 4.994e+00, Time: 0.82
# It: 200, Train Loss: 5.758e+00, Test Loss: 4.993e+00, Time: 0.81
# It: 300, Train Loss: 5.757e+00, Test Loss: 4.992e+00, Time: 0.83
# It: 400, Train Loss: 5.754e+00, Test Loss: 4.990e+00, Time: 0.84
# It: 500, Train Loss: 5.749e+00, Test Loss: 4.986e+00, Time: 0.83
# It: 600, Train Loss: 5.730e+00, Test Loss: 4.974e+00, Time: 0.83
# It: 700, Train Loss: 4.113e+00, Test Loss: 3.460e+00, Time: 0.83
# It: 800, Train Loss: 1.300e-01, Test Loss: 1.715e-01, Time: 0.95
# It: 900, Train Loss: 9.645e-04, Test Loss: 1.123e-03, Time: 1.10
# It: 1000, Train Loss: 9.520e-04, Test Loss: 1.102e-03, Time: 1.12
# It: 1100, Train Loss: 9.405e-04, Test Loss: 1.091e-03, Time: 0.82
# It: 1200, Train Loss: 9.294e-04, Test Loss: 1.080e-03, Time: 0.82
# It: 1300, Train Loss: 9.188e-04, Test Loss: 1.070e-03, Time: 0.83
# It: 1400, Train Loss: 9.086e-04, Test Loss: 1.060e-03, Time: 0.81
# It: 1500, Train Loss: 8.988e-04, Test Loss: 1.051e-03, Time: 0.81
# It: 1600, Train Loss: 8.893e-04, Test Loss: 1.041e-03, Time: 0.82
# It: 1700, Train Loss: 8.802e-04, Test Loss: 1.032e-03, Time: 0.82
# It: 1800, Train Loss: 8.713e-04, Test Loss: 1.023e-03, Time: 0.83
# It: 1900, Train Loss: 8.628e-04, Test Loss: 1.015e-03, Time: 0.80
# Training time: 17.4018
# Norm of Differnece: 1.390401e-02

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.002
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_train, x_train, title="Train/Test Set Ratio 0.001/0.999")
# Out:
# It: 0, Train Loss: 9.545e+00, Test Loss: 5.846e+00, Time: 0.27
# It: 100, Train Loss: 3.161e-01, Test Loss: 6.628e+01, Time: 1.52
# It: 200, Train Loss: 3.790e-03, Test Loss: 6.902e+01, Time: 1.40
# It: 300, Train Loss: 4.453e-05, Test Loss: 6.903e+01, Time: 1.14
# It: 400, Train Loss: 5.168e-07, Test Loss: 6.902e+01, Time: 1.17

# %% [markdown]
# ### Q.4 NOISE

# %%
# %matplotlib inline
def plotN(t_all, x_all, x_true, pred_all, t_train, x_train, title: str):
    fig = plt.figure(figsize=(21, 24))

    ax = plt.subplot(311)
    ax.plot(t_all, x_true, "r", label="Exact Solution")
    ax.plot(t_all, pred_all, "b--", label="Prediction")
    ax.scatter(t_train, x_train, s=30, c="g", label="Train Data Point")
    ax.legend()
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("$x$", fontsize = 12, rotation = 0)
    ax.set_title("$Fitting$", fontsize = 15)

    ax = plt.subplot(312)
    ax.plot(t_all, pred_all - x_all, "b-")
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("Prediction - Exact Solution", fontsize = 12, rotation = 90)
    ax.set_title("Difference between Prediction and Exact Solution", fontsize = 15)

    ax = plt.subplot(313)
    loss_train = np.array(model.loss_history["train"])
    loss_test = np.array(model.loss_history["test"])
    ax.scatter(np.arange(loss_train.size) * 100, loss_train, s=30, marker="x", label="Train Loss")
    ax.scatter(np.arange(loss_train.size) * 100, loss_test, s=30, marker="+", label="Test Loss")
    ax.legend()
    ax.set_xlabel("$iterations$", fontsize = 12)
    ax.set_ylabel("Loss", fontsize = 12, rotation = 90)
    ax.set_yscale("log")
    ax.set_title('Loss Curve', fontsize = 15)

    plt.gcf().text(0.02, 0.9, title, fontsize=20)

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all) + np.random.normal(loc=0.0, scale=0.01, size=t_all.shape)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plotN(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.01")
# Out:
# It: 0, Train Loss: 5.367e+00, Test Loss: 5.104e+00, Time: 0.16
# It: 100, Train Loss: 5.031e+00, Test Loss: 4.953e+00, Time: 1.21
# It: 200, Train Loss: 5.030e+00, Test Loss: 4.952e+00, Time: 1.35
# It: 300, Train Loss: 5.028e+00, Test Loss: 4.951e+00, Time: 3.11
# It: 400, Train Loss: 5.027e+00, Test Loss: 4.949e+00, Time: 1.79
# It: 500, Train Loss: 5.026e+00, Test Loss: 4.948e+00, Time: 1.19
# It: 600, Train Loss: 5.025e+00, Test Loss: 4.947e+00, Time: 1.20
# It: 700, Train Loss: 5.023e+00, Test Loss: 4.945e+00, Time: 1.19
# It: 800, Train Loss: 5.019e+00, Test Loss: 4.942e+00, Time: 1.20
# It: 900, Train Loss: 5.014e+00, Test Loss: 4.936e+00, Time: 1.23
# It: 1000, Train Loss: 5.000e+00, Test Loss: 4.922e+00, Time: 1.21
# It: 1100, Train Loss: 4.945e+00, Test Loss: 4.865e+00, Time: 1.21
# It: 1200, Train Loss: 2.878e-01, Test Loss: 3.043e-01, Time: 1.57
# It: 1300, Train Loss: 1.886e-02, Test Loss: 2.348e-02, Time: 1.67
# It: 1400, Train Loss: 1.626e-02, Test Loss: 2.029e-02, Time: 1.19
# It: 1500, Train Loss: 1.422e-02, Test Loss: 1.775e-02, Time: 1.64
# It: 1600, Train Loss: 1.259e-02, Test Loss: 1.570e-02, Time: 2.61
# It: 1700, Train Loss: 1.128e-02, Test Loss: 1.405e-02, Time: 2.04
# It: 1800, Train Loss: 1.021e-02, Test Loss: 1.269e-02, Time: 1.20
# It: 1900, Train Loss: 9.323e-03, Test Loss: 1.157e-02, Time: 1.31
# Training time: 31.0498
# Norm of Differnece: 4.519177e-02

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all) + np.random.normal(loc=0.0, scale=0.1, size=t_all.shape)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plotN(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.1")
# Out:
# It: 0, Train Loss: 5.572e+00, Test Loss: 5.333e+00, Time: 0.16
# It: 100, Train Loss: 5.032e+00, Test Loss: 5.384e+00, Time: 1.19
# It: 200, Train Loss: 5.031e+00, Test Loss: 5.383e+00, Time: 1.43
# It: 300, Train Loss: 5.029e+00, Test Loss: 5.382e+00, Time: 1.76
# It: 400, Train Loss: 5.028e+00, Test Loss: 5.381e+00, Time: 1.21
# It: 500, Train Loss: 5.027e+00, Test Loss: 5.380e+00, Time: 1.17
# It: 600, Train Loss: 5.026e+00, Test Loss: 5.378e+00, Time: 1.18
# It: 700, Train Loss: 5.024e+00, Test Loss: 5.376e+00, Time: 1.18
# It: 800, Train Loss: 5.020e+00, Test Loss: 5.372e+00, Time: 1.18
# It: 900, Train Loss: 5.007e+00, Test Loss: 5.355e+00, Time: 1.17
# It: 1000, Train Loss: 4.611e+00, Test Loss: 4.882e+00, Time: 1.18
# It: 1100, Train Loss: 3.147e-01, Test Loss: 2.793e-01, Time: 1.18
# It: 1200, Train Loss: 1.020e-01, Test Loss: 9.606e-02, Time: 1.44
# It: 1300, Train Loss: 1.020e-01, Test Loss: 9.605e-02, Time: 1.73
# It: 1400, Train Loss: 1.020e-01, Test Loss: 9.605e-02, Time: 1.16
# It: 1500, Train Loss: 1.019e-01, Test Loss: 9.604e-02, Time: 1.20
# It: 1600, Train Loss: 1.019e-01, Test Loss: 9.603e-02, Time: 1.18
# It: 1700, Train Loss: 1.019e-01, Test Loss: 9.602e-02, Time: 1.19
# It: 1800, Train Loss: 1.019e-01, Test Loss: 9.601e-02, Time: 1.17
# It: 1900, Train Loss: 1.019e-01, Test Loss: 9.601e-02, Time: 1.19
# Training time: 25.4901
# Norm of Differnece: 1.336690e-01

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all) + np.random.normal(loc=0.0, scale=0.5, size=t_all.shape)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plotN(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.5")
# Out:
# It: 0, Train Loss: 8.268e+00, Test Loss: 8.797e+00, Time: 0.40
# It: 100, Train Loss: 8.079e+00, Test Loss: 8.637e+00, Time: 2.44
# It: 200, Train Loss: 8.078e+00, Test Loss: 8.635e+00, Time: 2.84
# It: 300, Train Loss: 8.076e+00, Test Loss: 8.633e+00, Time: 1.26
# It: 400, Train Loss: 8.075e+00, Test Loss: 8.632e+00, Time: 1.20
# It: 500, Train Loss: 8.073e+00, Test Loss: 8.630e+00, Time: 1.17
# It: 600, Train Loss: 8.071e+00, Test Loss: 8.627e+00, Time: 1.16
# It: 700, Train Loss: 8.067e+00, Test Loss: 8.623e+00, Time: 1.18
# It: 800, Train Loss: 8.058e+00, Test Loss: 8.613e+00, Time: 1.20
# It: 900, Train Loss: 8.001e+00, Test Loss: 8.548e+00, Time: 1.19
# It: 1000, Train Loss: 3.159e+00, Test Loss: 2.720e+00, Time: 1.44
# It: 1100, Train Loss: 2.640e+00, Test Loss: 2.103e+00, Time: 1.77
# It: 1200, Train Loss: 2.638e+00, Test Loss: 2.105e+00, Time: 1.18
# It: 1300, Train Loss: 2.636e+00, Test Loss: 2.106e+00, Time: 1.17
# It: 1400, Train Loss: 2.635e+00, Test Loss: 2.107e+00, Time: 1.17
# It: 1500, Train Loss: 2.634e+00, Test Loss: 2.108e+00, Time: 1.16
# It: 1600, Train Loss: 2.634e+00, Test Loss: 2.109e+00, Time: 1.19
# It: 1700, Train Loss: 2.633e+00, Test Loss: 2.109e+00, Time: 1.18
# It: 1800, Train Loss: 2.633e+00, Test Loss: 2.110e+00, Time: 1.17
# It: 1900, Train Loss: 2.632e+00, Test Loss: 2.110e+00, Time: 1.17
# Training time: 28.1894
# Norm of Differnece: 4.847617e-01

# %% [markdown]
# ### Overfitting

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.1
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = np.sin(5 * t_all)+ np.random.normal(loc=0.0, scale=0.5, size=t_all.shape)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(20000, learning_rate=0.01, idxOpt=2)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plotN(t_all, x_all, x_true, pred_all, t_train, x_train, title="Overfitting Example: Noise ratio 0.5")
# Out:
# It: 0, Train Loss: 6.993e+00, Test Loss: 1.761e+01, Time: 0.19
# It: 100, Train Loss: 6.938e+00, Test Loss: 7.835e+00, Time: 3.82
# It: 200, Train Loss: 6.933e+00, Test Loss: 7.840e+00, Time: 4.52
# It: 300, Train Loss: 2.346e+00, Test Loss: 2.884e+00, Time: 3.79
# It: 400, Train Loss: 2.436e+00, Test Loss: 3.035e+00, Time: 3.83
# It: 500, Train Loss: 2.340e+00, Test Loss: 2.851e+00, Time: 4.61
# It: 600, Train Loss: 2.335e+00, Test Loss: 2.859e+00, Time: 3.82
# It: 700, Train Loss: 2.326e+00, Test Loss: 2.884e+00, Time: 3.89
# It: 800, Train Loss: 2.290e+00, Test Loss: 3.056e+00, Time: 4.68
# It: 900, Train Loss: 2.190e+00, Test Loss: 3.199e+00, Time: 3.89
# It: 1000, Train Loss: 2.165e+00, Test Loss: 3.171e+00, Time: 3.90
# It: 1100, Train Loss: 2.094e+00, Test Loss: 3.236e+00, Time: 4.65
# It: 1200, Train Loss: 1.883e+00, Test Loss: 3.815e+00, Time: 3.97
# It: 1300, Train Loss: 1.695e+00, Test Loss: 4.884e+00, Time: 3.95
# It: 1400, Train Loss: 1.759e+00, Test Loss: 4.977e+00, Time: 4.64
# It: 1500, Train Loss: 1.663e+00, Test Loss: 5.311e+00, Time: 3.87
# It: 1600, Train Loss: 1.490e+00, Test Loss: 5.612e+00, Time: 3.86
# It: 1700, Train Loss: 1.472e+00, Test Loss: 6.166e+00, Time: 4.69
# It: 1800, Train Loss: 1.457e+00, Test Loss: 6.034e+00, Time: 3.86
# It: 1900, Train Loss: 1.450e+00, Test Loss: 5.947e+00, Time: 3.80
# It: 2000, Train Loss: 1.451e+00, Test Loss: 5.985e+00, Time: 4.63
# It: 2100, Train Loss: 1.457e+00, Test Loss: 5.973e+00, Time: 3.93
# It: 2200, Train Loss: 1.438e+00, Test Loss: 6.060e+00, Time: 4.01
# It: 2300, Train Loss: 1.444e+00, Test Loss: 6.154e+00, Time: 4.71
# It: 2400, Train Loss: 1.433e+00, Test Loss: 6.132e+00, Time: 3.83
# It: 2500, Train Loss: 1.526e+00, Test Loss: 6.329e+00, Time: 3.90
# It: 2600, Train Loss: 1.430e+00, Test Loss: 6.176e+00, Time: 4.57
# It: 2700, Train Loss: 1.508e+00, Test Loss: 5.992e+00, Time: 3.88
# It: 2800, Train Loss: 1.438e+00, Test Loss: 6.292e+00, Time: 3.96
# It: 2900, Train Loss: 1.429e+00, Test Loss: 6.214e+00, Time: 4.67
# It: 3000, Train Loss: 1.426e+00, Test Loss: 6.270e+00, Time: 3.91
# It: 3100, Train Loss: 1.424e+00, Test Loss: 6.285e+00, Time: 4.21
# It: 3200, Train Loss: 1.426e+00, Test Loss: 6.248e+00, Time: 4.45
# It: 3300, Train Loss: 1.422e+00, Test Loss: 6.381e+00, Time: 3.92
# It: 3400, Train Loss: 1.452e+00, Test Loss: 6.273e+00, Time: 4.28
# It: 3500, Train Loss: 1.426e+00, Test Loss: 6.284e+00, Time: 4.41
# It: 3600, Train Loss: 1.427e+00, Test Loss: 6.356e+00, Time: 4.16
# It: 3700, Train Loss: 1.435e+00, Test Loss: 6.352e+00, Time: 4.74
# It: 3800, Train Loss: 1.422e+00, Test Loss: 6.457e+00, Time: 4.15
# It: 3900, Train Loss: 1.426e+00, Test Loss: 6.391e+00, Time: 3.92
# It: 4000, Train Loss: 1.419e+00, Test Loss: 6.387e+00, Time: 4.56
# It: 4100, Train Loss: 1.438e+00, Test Loss: 6.315e+00, Time: 4.91
# It: 4200, Train Loss: 1.418e+00, Test Loss: 6.483e+00, Time: 4.06
# It: 4300, Train Loss: 1.421e+00, Test Loss: 6.530e+00, Time: 4.75
# It: 4400, Train Loss: 1.453e+00, Test Loss: 6.645e+00, Time: 3.96
# It: 4500, Train Loss: 1.426e+00, Test Loss: 6.589e+00, Time: 3.90
# It: 4600, Train Loss: 1.418e+00, Test Loss: 6.502e+00, Time: 4.71
# It: 4700, Train Loss: 1.413e+00, Test Loss: 6.597e+00, Time: 3.86
# It: 4800, Train Loss: 1.406e+00, Test Loss: 6.678e+00, Time: 3.93
# It: 4900, Train Loss: 1.421e+00, Test Loss: 6.587e+00, Time: 4.66
# It: 5000, Train Loss: 1.405e+00, Test Loss: 6.789e+00, Time: 3.90
# It: 5100, Train Loss: 1.411e+00, Test Loss: 6.711e+00, Time: 3.94
# It: 5200, Train Loss: 1.427e+00, Test Loss: 6.848e+00, Time: 4.70
# It: 5300, Train Loss: 1.409e+00, Test Loss: 6.818e+00, Time: 3.87
# It: 5400, Train Loss: 1.414e+00, Test Loss: 6.754e+00, Time: 3.91
# It: 5500, Train Loss: 1.099e+00, Test Loss: 6.160e+00, Time: 4.70
# It: 5600, Train Loss: 9.444e-01, Test Loss: 8.844e+00, Time: 3.86
# It: 5700, Train Loss: 8.703e-01, Test Loss: 7.848e+00, Time: 3.85
# It: 5800, Train Loss: 8.001e-01, Test Loss: 7.364e+00, Time: 4.66
# It: 5900, Train Loss: 7.472e-01, Test Loss: 7.307e+00, Time: 3.84
# It: 6000, Train Loss: 7.969e-01, Test Loss: 6.927e+00, Time: 3.86
# It: 6100, Train Loss: 7.559e-01, Test Loss: 7.221e+00, Time: 4.60
# It: 6200, Train Loss: 8.397e-01, Test Loss: 7.637e+00, Time: 3.73
# It: 6300, Train Loss: 7.425e-01, Test Loss: 7.822e+00, Time: 3.82
# It: 6400, Train Loss: 7.557e-01, Test Loss: 7.594e+00, Time: 4.65
# It: 6500, Train Loss: 1.188e+00, Test Loss: 7.681e+00, Time: 3.89
# It: 6600, Train Loss: 7.003e-01, Test Loss: 7.343e+00, Time: 3.85
# It: 6700, Train Loss: 6.883e-01, Test Loss: 6.999e+00, Time: 4.69
# It: 6800, Train Loss: 6.551e-01, Test Loss: 6.765e+00, Time: 3.91
# It: 6900, Train Loss: 6.713e-01, Test Loss: 6.961e+00, Time: 3.87
# It: 7000, Train Loss: 6.561e-01, Test Loss: 7.281e+00, Time: 4.67
# It: 7100, Train Loss: 6.401e-01, Test Loss: 7.027e+00, Time: 3.89
# It: 7200, Train Loss: 6.446e-01, Test Loss: 7.877e+00, Time: 3.87
# It: 7300, Train Loss: 9.580e-01, Test Loss: 6.413e+00, Time: 4.62
# It: 7400, Train Loss: 1.034e+00, Test Loss: 6.338e+00, Time: 3.78
# It: 7500, Train Loss: 7.649e-01, Test Loss: 6.045e+00, Time: 3.82
# It: 7600, Train Loss: 7.870e-01, Test Loss: 6.221e+00, Time: 4.72
# It: 7700, Train Loss: 8.849e-01, Test Loss: 5.772e+00, Time: 3.86
# It: 7800, Train Loss: 7.286e-01, Test Loss: 5.828e+00, Time: 3.85
# It: 7900, Train Loss: 6.598e-01, Test Loss: 5.819e+00, Time: 4.63
# It: 8000, Train Loss: 6.416e-01, Test Loss: 5.809e+00, Time: 3.74
# It: 8100, Train Loss: 1.016e+00, Test Loss: 5.178e+00, Time: 3.78
# It: 8200, Train Loss: 6.711e-01, Test Loss: 5.566e+00, Time: 4.56
# It: 8300, Train Loss: 8.263e-01, Test Loss: 6.106e+00, Time: 3.84
# It: 8400, Train Loss: 7.266e-01, Test Loss: 5.593e+00, Time: 3.81
# It: 8500, Train Loss: 5.812e-01, Test Loss: 5.828e+00, Time: 4.59
# It: 8600, Train Loss: 7.303e-01, Test Loss: 5.555e+00, Time: 3.78
# It: 8700, Train Loss: 1.229e+00, Test Loss: 5.864e+00, Time: 3.75
# It: 8800, Train Loss: 1.211e+00, Test Loss: 5.768e+00, Time: 4.57
# It: 8900, Train Loss: 6.763e-01, Test Loss: 6.030e+00, Time: 3.76
# It: 9000, Train Loss: 6.047e-01, Test Loss: 5.990e+00, Time: 3.79
# It: 9100, Train Loss: 8.566e-01, Test Loss: 5.596e+00, Time: 4.55
# It: 9200, Train Loss: 7.902e-01, Test Loss: 5.666e+00, Time: 3.75
# It: 9300, Train Loss: 9.920e-01, Test Loss: 5.229e+00, Time: 3.86
# It: 9400, Train Loss: 7.105e-01, Test Loss: 5.856e+00, Time: 4.70
# It: 9500, Train Loss: 1.446e+00, Test Loss: 6.161e+00, Time: 3.84
# It: 9600, Train Loss: 4.999e-01, Test Loss: 6.125e+00, Time: 3.83
# It: 9700, Train Loss: 1.132e+00, Test Loss: 6.797e+00, Time: 4.50
# It: 9800, Train Loss: 1.048e+00, Test Loss: 6.711e+00, Time: 3.85
# It: 9900, Train Loss: 6.785e-01, Test Loss: 6.014e+00, Time: 3.77
# It: 10000, Train Loss: 7.948e-01, Test Loss: 6.030e+00, Time: 4.54
# It: 10100, Train Loss: 5.298e-01, Test Loss: 6.417e+00, Time: 3.86
# It: 10200, Train Loss: 5.634e-01, Test Loss: 5.634e+00, Time: 3.94
# It: 10300, Train Loss: 5.335e-01, Test Loss: 5.677e+00, Time: 4.65
# It: 10400, Train Loss: 7.310e-01, Test Loss: 5.840e+00, Time: 3.81
# It: 10500, Train Loss: 4.194e-01, Test Loss: 6.208e+00, Time: 3.83
# It: 10600, Train Loss: 5.694e-01, Test Loss: 5.620e+00, Time: 4.57
# It: 10700, Train Loss: 8.331e-01, Test Loss: 6.227e+00, Time: 3.92
# It: 10800, Train Loss: 1.334e+00, Test Loss: 6.661e+00, Time: 3.91
# It: 10900, Train Loss: 4.253e-01, Test Loss: 6.100e+00, Time: 4.63
# It: 11000, Train Loss: 5.501e-01, Test Loss: 6.419e+00, Time: 3.89
# It: 11100, Train Loss: 6.957e-01, Test Loss: 5.873e+00, Time: 3.78
# It: 11200, Train Loss: 6.457e-01, Test Loss: 6.219e+00, Time: 4.50
# It: 11300, Train Loss: 6.628e-01, Test Loss: 6.121e+00, Time: 3.69
# It: 11400, Train Loss: 8.228e-01, Test Loss: 5.509e+00, Time: 3.81
# It: 11500, Train Loss: 6.566e-01, Test Loss: 5.911e+00, Time: 4.69
# It: 11600, Train Loss: 3.879e-01, Test Loss: 6.618e+00, Time: 3.89
# It: 11700, Train Loss: 4.510e-01, Test Loss: 6.234e+00, Time: 3.84
# It: 11800, Train Loss: 4.803e-01, Test Loss: 6.254e+00, Time: 4.52
# It: 11900, Train Loss: 5.002e-01, Test Loss: 5.860e+00, Time: 3.68
# It: 12000, Train Loss: 8.909e-01, Test Loss: 6.300e+00, Time: 3.79
# It: 12100, Train Loss: 4.802e-01, Test Loss: 6.411e+00, Time: 4.32
# It: 12200, Train Loss: 4.407e-01, Test Loss: 6.353e+00, Time: 3.88
# It: 12300, Train Loss: 4.011e-01, Test Loss: 6.299e+00, Time: 3.71
# It: 12400, Train Loss: 6.314e-01, Test Loss: 5.714e+00, Time: 4.20
# It: 12500, Train Loss: 4.280e-01, Test Loss: 5.983e+00, Time: 4.07
# It: 12600, Train Loss: 4.178e-01, Test Loss: 6.100e+00, Time: 3.69
# It: 12700, Train Loss: 4.374e-01, Test Loss: 5.813e+00, Time: 3.89
# It: 12800, Train Loss: 4.455e-01, Test Loss: 5.818e+00, Time: 4.25
# It: 12900, Train Loss: 3.564e-01, Test Loss: 5.953e+00, Time: 3.69
# It: 13000, Train Loss: 5.640e-01, Test Loss: 5.266e+00, Time: 3.69
# It: 13100, Train Loss: 1.212e+00, Test Loss: 6.041e+00, Time: 4.46
# It: 13200, Train Loss: 3.672e-01, Test Loss: 5.982e+00, Time: 3.66
# It: 13300, Train Loss: 4.238e-01, Test Loss: 5.766e+00, Time: 3.69
# It: 13400, Train Loss: 5.346e-01, Test Loss: 6.231e+00, Time: 4.46
# It: 13500, Train Loss: 5.275e-01, Test Loss: 6.323e+00, Time: 3.76
# It: 13600, Train Loss: 5.136e-01, Test Loss: 6.397e+00, Time: 3.74
# It: 13700, Train Loss: 3.682e-01, Test Loss: 6.703e+00, Time: 4.46
# It: 13800, Train Loss: 5.952e-01, Test Loss: 6.754e+00, Time: 3.71
# It: 13900, Train Loss: 4.167e-01, Test Loss: 6.365e+00, Time: 3.70
# It: 14000, Train Loss: 3.429e-01, Test Loss: 6.675e+00, Time: 4.47
# It: 14100, Train Loss: 4.319e-01, Test Loss: 6.696e+00, Time: 3.66
# It: 14200, Train Loss: 3.633e-01, Test Loss: 6.640e+00, Time: 3.69
# It: 14300, Train Loss: 7.232e-01, Test Loss: 5.828e+00, Time: 4.52
# It: 14400, Train Loss: 2.728e-01, Test Loss: 6.007e+00, Time: 3.77
# It: 14500, Train Loss: 1.002e+00, Test Loss: 6.338e+00, Time: 3.78
# It: 14600, Train Loss: 4.654e-01, Test Loss: 6.902e+00, Time: 4.57
# It: 14700, Train Loss: 3.941e-01, Test Loss: 7.174e+00, Time: 3.77
# It: 14800, Train Loss: 4.905e-01, Test Loss: 6.455e+00, Time: 3.79
# It: 14900, Train Loss: 5.572e-01, Test Loss: 6.865e+00, Time: 4.37
# It: 15000, Train Loss: 3.293e-01, Test Loss: 6.940e+00, Time: 3.99
# It: 15100, Train Loss: 2.783e-01, Test Loss: 6.918e+00, Time: 3.74
# It: 15200, Train Loss: 3.286e-01, Test Loss: 6.339e+00, Time: 4.31
# It: 15300, Train Loss: 4.283e-01, Test Loss: 6.267e+00, Time: 4.11
# It: 15400, Train Loss: 8.832e-01, Test Loss: 4.990e+00, Time: 3.83
# It: 15500, Train Loss: 6.309e-01, Test Loss: 5.763e+00, Time: 4.28
# It: 15600, Train Loss: 3.581e-01, Test Loss: 6.542e+00, Time: 4.14
# It: 15700, Train Loss: 3.130e-01, Test Loss: 6.722e+00, Time: 3.74
# It: 15800, Train Loss: 5.563e-01, Test Loss: 5.693e+00, Time: 4.18
# It: 15900, Train Loss: 4.992e-01, Test Loss: 6.611e+00, Time: 4.25
# It: 16000, Train Loss: 5.052e-01, Test Loss: 5.897e+00, Time: 3.71
# It: 16100, Train Loss: 4.325e-01, Test Loss: 5.864e+00, Time: 4.06
# It: 16200, Train Loss: 3.563e-01, Test Loss: 6.503e+00, Time: 4.29
# It: 16300, Train Loss: 3.564e-01, Test Loss: 6.317e+00, Time: 3.75
# It: 16400, Train Loss: 2.997e-01, Test Loss: 6.565e+00, Time: 3.80
# It: 16500, Train Loss: 2.610e-01, Test Loss: 6.595e+00, Time: 4.48
# It: 16600, Train Loss: 2.982e-01, Test Loss: 6.418e+00, Time: 4.55
# It: 16700, Train Loss: 2.379e-01, Test Loss: 6.404e+00, Time: 6.62
# It: 16800, Train Loss: 3.204e-01, Test Loss: 5.993e+00, Time: 3.78
# It: 16900, Train Loss: 3.033e-01, Test Loss: 5.851e+00, Time: 3.87
# It: 17000, Train Loss: 1.148e+00, Test Loss: 6.205e+00, Time: 4.52
# It: 17100, Train Loss: 7.623e-01, Test Loss: 6.304e+00, Time: 3.71
# It: 17200, Train Loss: 4.135e-01, Test Loss: 6.652e+00, Time: 3.83
# It: 17300, Train Loss: 6.828e-01, Test Loss: 6.601e+00, Time: 4.57
# It: 17400, Train Loss: 5.430e-01, Test Loss: 5.198e+00, Time: 3.79
# It: 17500, Train Loss: 3.495e-01, Test Loss: 5.417e+00, Time: 3.94
# It: 17600, Train Loss: 6.454e-01, Test Loss: 5.608e+00, Time: 4.66
# It: 17700, Train Loss: 4.542e-01, Test Loss: 5.413e+00, Time: 3.83
# It: 17800, Train Loss: 5.593e-01, Test Loss: 6.008e+00, Time: 3.80
# It: 17900, Train Loss: 7.803e-01, Test Loss: 5.752e+00, Time: 4.51
# It: 18000, Train Loss: 5.569e-01, Test Loss: 5.786e+00, Time: 3.76
# It: 18100, Train Loss: 1.120e+00, Test Loss: 5.506e+00, Time: 3.72
# It: 18200, Train Loss: 5.551e-01, Test Loss: 5.370e+00, Time: 4.49
# It: 18300, Train Loss: 6.556e-01, Test Loss: 6.136e+00, Time: 3.86
# It: 18400, Train Loss: 5.856e-01, Test Loss: 5.798e+00, Time: 3.78
# It: 18500, Train Loss: 3.084e-01, Test Loss: 5.794e+00, Time: 4.26
# It: 18600, Train Loss: 2.626e-01, Test Loss: 5.683e+00, Time: 3.98
# It: 18700, Train Loss: 3.792e-01, Test Loss: 5.421e+00, Time: 3.68
# It: 18800, Train Loss: 5.476e-01, Test Loss: 5.301e+00, Time: 4.11
# It: 18900, Train Loss: 5.088e-01, Test Loss: 5.283e+00, Time: 4.18
# It: 19000, Train Loss: 4.059e-01, Test Loss: 5.624e+00, Time: 3.74
# It: 19100, Train Loss: 1.121e+00, Test Loss: 5.512e+00, Time: 3.93
# It: 19200, Train Loss: 3.884e-01, Test Loss: 5.518e+00, Time: 4.28
# It: 19300, Train Loss: 3.347e-01, Test Loss: 6.122e+00, Time: 3.70
# It: 19400, Train Loss: 4.550e-01, Test Loss: 5.552e+00, Time: 3.84
# It: 19500, Train Loss: 3.857e-01, Test Loss: 5.386e+00, Time: 4.46
# It: 19600, Train Loss: 2.209e-01, Test Loss: 6.253e+00, Time: 3.72
# It: 19700, Train Loss: 5.111e-01, Test Loss: 5.566e+00, Time: 3.78
# It: 19800, Train Loss: 3.336e-01, Test Loss: 6.082e+00, Time: 4.51
# It: 19900, Train Loss: 4.582e-01, Test Loss: 5.425e+00, Time: 3.73
# Training time: 819.8930
# Norm of Differnece: 8.461095e-01
