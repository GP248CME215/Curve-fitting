# %%
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.layers import InputLayer, Dense, Layer
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(123)
tf.random.set_seed(123)

# %%
class NeuralNet:
    # Initialize the class
    def __init__(self, t_train, x_train, t_test, x_test, layers, t_min, t_max):
        self.t_train = t_train
        self.x_train = x_train
        self.t_test = t_test
        self.x_test = x_test
        self.loss_history = {"train": [], "test": []}
        
        # Initialize NNs with given number of layers and domain bounds [t_min, tmax]
        self.t_min = t_min
        self.t_max = t_max
        self.initialize_nn(layers)
    
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def initialize_nn(self, layers):        
        """Functions used to establish the initial neural network"""
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32))
            weights.append(W)
            biases.append(b)        
        self.weights = weights
        self.biases = biases
        self.trainable_variables = self.weights + self.biases
       
    def net(self, X):
        H = 2.0 * (X - self.t_min) / (self.t_max - self.t_min) - 1.0
        for l in range(0, len(self.weights) - 1):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    @tf.function
    def loss_train(self):
        x_pred = self.net(self.t_train)
        loss = tf.reduce_mean(tf.square(self.x_train - x_pred)) * 10
        return loss
    
    @tf.function
    def loss_test(self):
        x_pred = self.net(self.t_test)
        loss = tf.reduce_mean(tf.square(self.x_test - x_pred)) * 10
        return loss

    def get_test_error(self):
        x_pred = self.net(self.t_test)
        error_x = tf.norm(self.x_test - x_pred, 2) / tf.norm(self.x_test, 2)
        return error_x
    
    def train(self, nIter: int, learning_rate: float, idxOpt: int):
        """Function used for training the model"""
        if idxOpt == 1:
            # mode 1: running the Gradient Descent optimization
            self.optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
        elif idxOpt == 2:
            # mode 2: running the Adam optimization
            self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        else:
            raise ValueError("Unsupported idxOpt")

        varlist = self.trainable_variables
        start_time = time.time()

        for it in range(nIter):
            self.optimizer.minimize(self.loss_train, varlist)
            
            # Print
            if it % 100 == 0:
                elapsed = time.time() - start_time
                loss_train = self.loss_train().numpy()
                loss_test = self.loss_test().numpy()
                self.loss_history["train"].append(loss_train)
                self.loss_history["test"].append(loss_test)
                print('It: %d, Train Loss: %.3e, Test Loss: %.3e, Time: %.2f' % 
                      (it, loss_train, loss_test, elapsed))
                start_time = time.time()

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_all = x = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

# %%
# %matplotlib inline
def plot(t_all, x_all, pred_all, t_test, x_test, title: str):
    fig = plt.figure(figsize=(21, 24))

    ax = plt.subplot(311)
    ax.plot(t_all, x_all, "r", label="Exact Solution")
    ax.plot(t_all, pred_all, "b--", label="Prediction")
    ax.scatter(t_test, x_test, s=30, c="g", label="Test Data Point")
    ax.legend()
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("$x$", fontsize = 12, rotation = 0)
    ax.set_title("$Fitting$", fontsize = 15)

    ax = plt.subplot(312)
    ax.plot(t_all, pred_all - x_all, "b-")
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("Prediction - Exact Solution", fontsize = 12, rotation = 90)
    ax.set_title("Difference between Prediction and Exact Solution", fontsize = 15)

    ax = plt.subplot(313)
    loss_train = np.array(model.loss_history["train"])
    loss_test = np.array(model.loss_history["test"])
    ax.scatter(np.arange(loss_train.size) * 100, loss_train, s=30, marker="x", label="Train Loss")
    ax.scatter(np.arange(loss_train.size) * 100, loss_test, s=30, marker="+", label="Test Loss")
    ax.legend()
    ax.set_xlabel("$iterations$", fontsize = 12)
    ax.set_ylabel("Loss", fontsize = 12, rotation = 90)
    ax.set_yscale("log")
    ax.set_title('Loss Curve', fontsize = 15)
    
    plt.gcf().text(0.02, 0.9, title, fontsize=20)

# %%
model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()                
model.train(2000, learning_rate=0.1, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_test, x_test, title="Learning rate 0.1")
# Out:
# It: 0, Train Loss: 6.856e+00, Test Loss: 6.457e+00, Time: 0.14
# It: 100, Train Loss: 1.403e+02, Test Loss: 1.406e+02, Time: 0.56
# It: 200, Train Loss: 1.054e+02, Test Loss: 1.013e+02, Time: 0.62
# It: 300, Train Loss: 9.895e+01, Test Loss: 1.029e+02, Time: 0.57
# It: 400, Train Loss: 8.198e+01, Test Loss: 8.231e+01, Time: 0.54
# It: 500, Train Loss: 6.362e+01, Test Loss: 7.460e+01, Time: 0.53
# It: 600, Train Loss: 2.721e+01, Test Loss: 2.903e+01, Time: 0.54
# It: 700, Train Loss: 1.197e+01, Test Loss: 1.152e+01, Time: 0.54
# It: 800, Train Loss: 2.339e+01, Test Loss: 2.538e+01, Time: 0.56
# It: 900, Train Loss: 1.627e+01, Test Loss: 1.608e+01, Time: 0.53
# It: 1000, Train Loss: 1.255e+01, Test Loss: 1.379e+01, Time: 0.54
# It: 1100, Train Loss: 1.114e+01, Test Loss: 1.177e+01, Time: 0.58
# It: 1200, Train Loss: 9.064e+00, Test Loss: 9.890e+00, Time: 0.59
# It: 1300, Train Loss: 1.142e+01, Test Loss: 1.080e+01, Time: 0.54
# It: 1400, Train Loss: 1.072e+01, Test Loss: 1.169e+01, Time: 0.54
# It: 1500, Train Loss: 1.592e+01, Test Loss: 1.694e+01, Time: 0.53
# It: 1600, Train Loss: 1.779e+01, Test Loss: 1.666e+01, Time: 0.56
# It: 1700, Train Loss: 1.820e+01, Test Loss: 1.876e+01, Time: 0.56
# It: 1800, Train Loss: 7.394e+00, Test Loss: 7.436e+00, Time: 0.55
# It: 1900, Train Loss: 6.184e+00, Test Loss: 6.312e+00, Time: 0.53
# Training time: 11.2995
# Norm of Differnece: 1.011772e+00

# %%
model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()                
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_test, x_test, title="Learning rate 0.01")
# Out:
# It: 0, Train Loss: 5.497e+00, Test Loss: 5.426e+00, Time: 0.15
# It: 100, Train Loss: 5.051e+00, Test Loss: 4.819e+00, Time: 0.54
# It: 200, Train Loss: 5.048e+00, Test Loss: 4.815e+00, Time: 0.55
# It: 300, Train Loss: 5.039e+00, Test Loss: 4.808e+00, Time: 0.55
# It: 400, Train Loss: 4.872e+00, Test Loss: 4.659e+00, Time: 0.54
# It: 500, Train Loss: 2.368e-03, Test Loss: 2.693e-03, Time: 0.57
# It: 600, Train Loss: 2.109e-03, Test Loss: 2.094e-03, Time: 0.53
# It: 700, Train Loss: 2.078e-03, Test Loss: 2.063e-03, Time: 0.54
# It: 800, Train Loss: 2.047e-03, Test Loss: 2.033e-03, Time: 0.53
# It: 900, Train Loss: 2.018e-03, Test Loss: 2.005e-03, Time: 0.54
# It: 1000, Train Loss: 1.989e-03, Test Loss: 1.977e-03, Time: 0.53
# It: 1100, Train Loss: 1.962e-03, Test Loss: 1.950e-03, Time: 0.54
# It: 1200, Train Loss: 1.935e-03, Test Loss: 1.924e-03, Time: 0.67
# It: 1300, Train Loss: 1.909e-03, Test Loss: 1.898e-03, Time: 0.62
# It: 1400, Train Loss: 1.884e-03, Test Loss: 1.874e-03, Time: 0.61
# It: 1500, Train Loss: 1.860e-03, Test Loss: 1.850e-03, Time: 0.62
# It: 1600, Train Loss: 1.836e-03, Test Loss: 1.827e-03, Time: 0.53
# It: 1700, Train Loss: 1.813e-03, Test Loss: 1.804e-03, Time: 0.54
# It: 1800, Train Loss: 1.791e-03, Test Loss: 1.783e-03, Time: 0.54
# It: 1900, Train Loss: 1.769e-03, Test Loss: 1.761e-03, Time: 0.54
# Training time: 11.4260
# Norm of Differnece: 1.834102e-02

# %%
model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()                
model.train(2000, learning_rate=0.001, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, pred_all, t_test, x_test, title="Learning rate 0.001")
# Out:
# It: 0, Train Loss: 5.916e+00, Test Loss: 5.911e+00, Time: 0.16
# It: 100, Train Loss: 5.057e+00, Test Loss: 4.826e+00, Time: 0.54
# It: 200, Train Loss: 5.057e+00, Test Loss: 4.824e+00, Time: 0.55
# It: 300, Train Loss: 5.057e+00, Test Loss: 4.824e+00, Time: 0.54
# It: 400, Train Loss: 5.056e+00, Test Loss: 4.824e+00, Time: 0.54
# It: 500, Train Loss: 5.056e+00, Test Loss: 4.823e+00, Time: 0.58
# It: 600, Train Loss: 5.056e+00, Test Loss: 4.823e+00, Time: 0.54
# It: 700, Train Loss: 5.056e+00, Test Loss: 4.823e+00, Time: 0.55
# It: 800, Train Loss: 5.055e+00, Test Loss: 4.822e+00, Time: 0.54
# It: 900, Train Loss: 5.055e+00, Test Loss: 4.822e+00, Time: 0.54
# It: 1000, Train Loss: 5.055e+00, Test Loss: 4.822e+00, Time: 0.54
# It: 1100, Train Loss: 5.055e+00, Test Loss: 4.822e+00, Time: 0.53
# It: 1200, Train Loss: 5.054e+00, Test Loss: 4.822e+00, Time: 0.54
# It: 1300, Train Loss: 5.054e+00, Test Loss: 4.821e+00, Time: 0.55
# It: 1400, Train Loss: 5.054e+00, Test Loss: 4.821e+00, Time: 0.53
# It: 1500, Train Loss: 5.054e+00, Test Loss: 4.821e+00, Time: 0.54
# It: 1600, Train Loss: 5.053e+00, Test Loss: 4.821e+00, Time: 0.59
# It: 1700, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 0.54
# It: 1800, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 0.54
# It: 1900, Train Loss: 5.053e+00, Test Loss: 4.820e+00, Time: 0.54
# Training time: 11.1584
# Norm of Differnece: 9.650439e-01
